# %% [markdown]
# - https://requests.readthedocs.io/en/latest/

# %%
from dotenv import find_dotenv, load_dotenv
import requests
import os

# %%
_ = load_dotenv(find_dotenv())

# %%
_
# Out:
# True

# %%
# .env se username aur password (token) lo
USERNAME = os.getenv("GITHUB_USERNAME")
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")

# Agar values na mile to error aaye
if not USERNAME or not GITHUB_TOKEN:
    print("❌ .env file me GITHUB_USERNAME ya GITHUB_PASSWORD nahi mila!")
else:
    # Request bhejo
    response = requests.get('https://api.github.com/user', auth=(USERNAME, GITHUB_TOKEN))

    # Status code check karo
    if response.status_code == 200:
        print("✅ Login successful!")
        print(response.json())  # JSON data print hoga
    else:
        print(f"❌ Error: {response.status_code}")
        print(response.json())

# %%
headers = {
    'Authorization': f'token {GITHUB_TOKEN}',
    'Accept': 'application/vnd.github.v3+json'
}

response = requests.get('https://api.github.com/user', headers=headers)

# %%
response.json()

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '52438791403',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 935174008,
#    'name': 'parkdohyeon0428/seoul_weather',
#    'url': 'https://api.github.com/repos/parkdohyeon0428/seoul_weather'},
#   'payload': {'repository_id': 935174008,
#    'push_id': 25672883016,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '35942cf560fc4c7b4a1dea402ad8a44cdf951ed8',
#    'before': 'b0090ec26b95b72f76284feec6bd252c544b4601',
#    'commits': [{'sha': '35942cf560fc4c7b4a1dea402ad8a44cdf951ed8',
#      'author': {'email': 'github-actions@github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update weather data (auto)',
#      'distinct': True,
# ...

# %%
r = requests.post('https://httpbin.org/post', data={'Name': 'Farhan'})
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'Name': 'Farhan'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '11',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6880c2e4-7172697a509a2cf156fc3f9e'},
#  'json': None,
#  'origin': '110.37.119.232',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.put('https://httpbin.org/put', data={'Name': 'Farhan'})
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'Name': 'Farhan'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '11',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6880c2d2-45c245f30af1625c00019bce'},
#  'json': None,
#  'origin': '110.37.119.232',
#  'url': 'https://httpbin.org/put'}

# %%
r = requests.delete('https://httpbin.org/delete')
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6880c2f5-68d0358534aea6d743404611'},
#  'json': None,
#  'origin': '110.37.119.232',
#  'url': 'https://httpbin.org/delete'}

# %%
r = requests.head('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %%
r = requests.options('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %% [markdown]
# ## **Passing Parameters In URLs**

# %%
payload = {'Name': 'Farhan', 'Role': 'ML Engineer'}
r = requests.get('https://httpbin.org/get', params=payload)
r.json()
# Out:
# {'args': {'Name': 'Farhan', 'Role': 'ML Engineer'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6880c38b-396954a135445751634aaf9f'},
#  'origin': '110.37.119.232',
#  'url': 'https://httpbin.org/get?Name=Farhan&Role=ML+Engineer'}

# %% [markdown]
# ## **Response Content**

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"52440340788","type":"PushEvent","actor":{"id":172744619,"login":"comfy-pr-bot","display_login":"comfy-pr-bot","gravatar_id":"","url":"https://api.github.com/users/comfy-pr-bot","avatar_url":"https://avatars.githubusercontent.com/u/172744619?"},"repo":{"id":842326928,"name":"ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646","url":"https://api.github.com/repos/ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646"},"payload":{"repository_id":842326928,"push_id":25673630851,"size":1,"distinct_size":1,"ref":"refs/heads/pyproject","head":"ce77ed163b055a778fb45e5243e5de56e924019c","before":"057e51e0eab186454b7335ea2a3e7cce73d7d028","commits":[{"sha":"ce77ed163b055a778fb45e5243e5de56e924019c","author":{"email":"async () = process.env.GIT_USEREMAIL || (await ghUser()).email && (await ghUser()).email || DIE(\\"Missing env.GIT_USEREMAIL\\")","name":"async () = process.env.GIT_USERNAME || (await ghUser()).email && (await ghUser()).name || DIE(\\"Missing env.GIT_USERNAME\\")"},"message":"chore
# ...

# %%
r.json()
# Out:
# [{'id': '52440340788',
#   'type': 'PushEvent',
#   'actor': {'id': 172744619,
#    'login': 'comfy-pr-bot',
#    'display_login': 'comfy-pr-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/comfy-pr-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/172744619?'},
#   'repo': {'id': 842326928,
#    'name': 'ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646',
#    'url': 'https://api.github.com/repos/ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646'},
#   'payload': {'repository_id': 842326928,
#    'push_id': 25673630851,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/pyproject',
#    'head': 'ce77ed163b055a778fb45e5243e5de56e924019c',
#    'before': '057e51e0eab186454b7335ea2a3e7cce73d7d028',
#    'commits': [{'sha': 'ce77ed163b055a778fb45e5243e5de56e924019c',
#      'author': {'email': 'async () = process.env.GIT_USEREMAIL || (await ghUser()).email && (await ghUser()).email || DIE("Missing env.GIT_USEREMAIL")',
# ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'
r.encoding
# Out:
# 'ISO-8859-1'

# %% [markdown]
# ## **Binary Response Content**

# %%
r.content
# Out:
# b'[{"id":"52440340788","type":"PushEvent","actor":{"id":172744619,"login":"comfy-pr-bot","display_login":"comfy-pr-bot","gravatar_id":"","url":"https://api.github.com/users/comfy-pr-bot","avatar_url":"https://avatars.githubusercontent.com/u/172744619?"},"repo":{"id":842326928,"name":"ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646","url":"https://api.github.com/repos/ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646"},"payload":{"repository_id":842326928,"push_id":25673630851,"size":1,"distinct_size":1,"ref":"refs/heads/pyproject","head":"ce77ed163b055a778fb45e5243e5de56e924019c","before":"057e51e0eab186454b7335ea2a3e7cce73d7d028","commits":[{"sha":"ce77ed163b055a778fb45e5243e5de56e924019c","author":{"email":"async () = process.env.GIT_USEREMAIL || (await ghUser()).email && (await ghUser()).email || DIE(\\"Missing env.GIT_USEREMAIL\\")","name":"async () = process.env.GIT_USERNAME || (await ghUser()).email && (await ghUser()).name || DIE(\\"Missing env.GIT_USERNAME\\")"},"message":"chor
# ...

# %%
display(r.content)
# Out:
# b'[{"id":"52440340788","type":"PushEvent","actor":{"id":172744619,"login":"comfy-pr-bot","display_login":"comfy-pr-bot","gravatar_id":"","url":"https://api.github.com/users/comfy-pr-bot","avatar_url":"https://avatars.githubusercontent.com/u/172744619?"},"repo":{"id":842326928,"name":"ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646","url":"https://api.github.com/repos/ComfyNodePRs/PR-ComfyUI-TiledDiffusion-8fd6e646"},"payload":{"repository_id":842326928,"push_id":25673630851,"size":1,"distinct_size":1,"ref":"refs/heads/pyproject","head":"ce77ed163b055a778fb45e5243e5de56e924019c","before":"057e51e0eab186454b7335ea2a3e7cce73d7d028","commits":[{"sha":"ce77ed163b055a778fb45e5243e5de56e924019c","author":{"email":"async () = process.env.GIT_USEREMAIL || (await ghUser()).email && (await ghUser()).email || DIE(\\"Missing env.GIT_USEREMAIL\\")","name":"async () = process.env.GIT_USERNAME || (await ghUser()).email && (await ghUser()).name || DIE(\\"Missing env.GIT_USERNAME\\")"},"message":"chor
# ...

# %%
# to create an image from binary data returned by a request

from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))

# %% [markdown]
# ## **JSON Response Content**

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '52440606649',
#   'type': 'PushEvent',
#   'actor': {'id': 197639564,
#    'login': 'alexvera626',
#    'display_login': 'alexvera626',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexvera626',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/197639564?'},
#   'repo': {'id': 933684845,
#    'name': 'alexvera626/ADSB',
#    'url': 'https://api.github.com/repos/alexvera626/ADSB'},
#   'payload': {'repository_id': 933684845,
#    'push_id': 25673757013,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '24689f6159f58411d079580edadd7b30251588e7',
#    'before': '8aa335e45fe62a2f79d5e09eb42ff1c1cf443913',
#    'commits': [{'sha': '24689f6159f58411d079580edadd7b30251588e7',
#      'author': {'email': 'alexvera626@icloud.com', 'name': 'alexvera626'},
#      'message': 'Upload oga_tracks.geojson',
#      'distinct': True,
# ...

# %% [markdown]
# ## **Response Status Codes**

# %%
r = requests.get('https://httpbin.org/get')
r.status_code
# Out:
# 200

# %%
r.status_code == requests.codes.ok
# Out:
# True

# %% [markdown]
# ## **Response Headers**

# %%
r.headers
# Out:
# {'Date': 'Wed, 23 Jul 2025 11:22:27 GMT', 'Content-Type': 'application/json', 'Content-Length': '308', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.headers.get('content-type')
# Out:
# 'application/json'

# %% [markdown]
# ## **Cookies**

# %%
# If a response contains some Cookies, you can quickly access them:

url = 'https://httpbin.org/get'
r = requests.get(url)
r.json()

# r.cookies['example_cookie_name']   # to get cookie
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6880c748-60520ccb349471cd0f058111'},
#  'origin': '110.37.119.232',
#  'url': 'https://httpbin.org/get'}

# %%
# To send your own cookies to the server, you can use the cookies parameter:

url = 'https://httpbin.org/cookies'
cookies = dict(cookies_are='working')

r = requests.get(url, cookies=cookies)
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %% [markdown]
# Cookies are returned in a `RequestsCookieJar`, which acts like a dict but also offers a more complete interface, suitable for use over multiple domains or paths. Cookie jars can also be passed in to requests:

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('tasty_cookie', 'yum', domain='httpbin.org', path='/cookies')
jar.set('gross_cookie', 'blech', domain='httpbin.org', path='/elsewhere')
url = 'https://httpbin.org/cookies'
r = requests.get(url, cookies=jar)
r.text
# Out:
# '{\n  "cookies": {\n    "tasty_cookie": "yum"\n  }\n}\n'

# %% [markdown]
# ## **Redirection and History¶**

# %%
r = requests.get('http://github.com/')
print(r.url)

print(r.status_code)
print(r.history)
# Out:
# https://github.com/
# 200
# [<Response [301]>]

# %% [markdown]
# If you’re using GET, OPTIONS, POST, PUT, PATCH or DELETE, you can disable redirection handling with the allow_redirects parameter:

# %%
r = requests.get('http://github.com/', allow_redirects=False)
print(r.status_code)

print(r.history)
# Out:
# 301
# []

# %% [markdown]
# If you’re using HEAD, you can enable redirection as well:

# %%
r = requests.head('http://github.com/', allow_redirects=True)

print(r.url)
print(r.history)
# Out:
# https://github.com/
# [<Response [301]>]

# %% [markdown]
# ## **Timeouts**

# %%
requests.get('https://github.com/', timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\FarhanArain\anaconda3\envs\streamlit\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\FarhanArain\anaconda3\envs\streamlit\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
